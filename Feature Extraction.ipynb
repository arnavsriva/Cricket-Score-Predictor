# %%
import pandas as pd
import pickle

# %%
data = pickle.load(open('data_v2.pkl','rb'))

# %%
data
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed     city  \
# 0           2    Australia    Sri Lanka   0.1     0                0      NaN
# 1           2    Australia    Sri Lanka   0.2     0                0      NaN
# 2           2    Australia    Sri Lanka   0.3     1                0      NaN
# 3           2    Australia    Sri Lanka   0.4     2                0      NaN
# 4           2    Australia    Sri Lanka   0.5     0                0      NaN
# ..        ...          ...          ...   ...   ...              ...      ...
# 121       964    Sri Lanka    Australia  19.3     1                0  Colombo
# 122       964    Sri Lanka    Australia  19.4     0                0  Colombo
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva  Colombo
# 124       964    Sri Lanka    Australia  19.6     2                0  Colombo
# 125       964    Sri Lanka    Australia  19.7     1                0  Colombo
#
#                         venue
# ...

# %%
data.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8548
# venue                  0
# dtype: int64

# %%
data['city'].isnull()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 121    False
# 122    False
# 123    False
# 124    False
# 125    False
# Name: city, Length: 63888, dtype: bool

# %%
import numpy as np
cities = np.where(data['city'].isnull(), data['venue'].str.split().apply(lambda x: x[0]),data['city'])

# %%
data['city'] = cities

# %%
data.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
data.drop(columns=['venue'], inplace= True)

# %%
eligible_cities = data['city'].value_counts()[data['city'].value_counts()>600].index.tolist()

# %%
data = data[data['city'].isin(eligible_cities)]

# %%
data
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1                0
# 122       964    Sri Lanka    Australia  19.4     0                0
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2                0
# 125       964    Sri Lanka    Australia  19.7     1                0
#
#           city
# 0    Melbourne
# 1    Melbourne
# 2    Melbourne
# 3    Melbourne
# 4    Melbourne
# ..         ...
# 121    Colombo
# ...

# %%
data['current_score'] = data.groupby('match_id').cumsum()['runs']
# Out:
# <ipython-input-13-bb2a6ed0be73>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['current_score'] = data.groupby('match_id').cumsum()['runs']

# %%
data['over'] = data['ball'].apply(lambda x:str(x).split(".")[0])
data['ball_no'] = data['ball'].apply(lambda x:str(x).split(".")[1])
data
# Out:
# <ipython-input-15-640623bce981>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['over'] = data['ball'].apply(lambda x:str(x).split(".")[0])
# <ipython-input-15-640623bce981>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ball_no'] = data['ball'].apply(lambda x:str(x).split(".")[1])
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# ...

# %%
data['balls_bowled'] = (data['over'].astype('int')*6) + data['ball_no'].astype('int')
data
# Out:
# <ipython-input-16-3da986a215d9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['balls_bowled'] = (data['over'].astype('int')*6) + data['ball_no'].astype('int')
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1                0
# ...

# %%
data['balls_left'] = 120 - data['balls_bowled']
data['balls_left'] = data['balls_left'].apply(lambda x:0 if x<0 else x)
data
# Out:
# <ipython-input-17-c295df427956>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['balls_left'] = 120 - data['balls_bowled']
# <ipython-input-17-c295df427956>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['balls_left'] = data['balls_left'].apply(lambda x:0 if x<0 else x)
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# ...

# %%
data['player_dismissed'] = data['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
data['player_dismissed'] = data['player_dismissed'].astype('int')
data['player_dismissed'] = data.groupby('match_id').cumsum()['player_dismissed']
data['wickets_left'] = 10 - data['player_dismissed']
# Out:
# <ipython-input-18-6bea22aa751d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['player_dismissed'] = data['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
# <ipython-input-18-6bea22aa751d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['player_dismissed'] = data['player_dismissed'].astype('int')
# <ipython-input-18-6bea22aa751d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
data['crr'] = (data['current_score']*6)/data['balls_bowled']
# Out:
# <ipython-input-19-4123403fad62>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['crr'] = (data['current_score']*6)/data['balls_bowled']

# %%
groups = data.groupby('match_id')

match_ids = data['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())

# %%
data['last_five'] = last_five
# Out:
# <ipython-input-21-1d0af3e58c03>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['last_five'] = last_five

# %%
final_df = data.groupby('match_id').sum()['runs'].reset_index().merge(data,on='match_id')

# %%
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# last_five        0
# runs_x           0
# dtype: int64

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.sample(2)
# Out:
#       batting_team  bowling_team          city  current_score  balls_left  \
# 36661  New Zealand     Sri Lanka     Pallekele             28          63
# 18589  West Indies  South Africa  Johannesburg             72          37
#
#        wickets_left       crr  last_five  runs_x
# 36661             4  2.947368       16.0      74
# 18589             5  5.204819       30.0     131

# %%
X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#       batting_team bowling_team         city  current_score  balls_left  \
# 31759     Pakistan  New Zealand    Pallekele             41          91
# 48639      England    Sri Lanka        Delhi             75          52
# 45350    Sri Lanka      England  Southampton             47          84
# 18984    Australia      England   Manchester             48          79
# 27724    Australia      England    Melbourne             72          64
# ...            ...          ...          ...            ...         ...
# 23942     Pakistan   Bangladesh     St Lucia            147          19
# 47070     Pakistan   Bangladesh      Kolkata            121          37
# 21445    Sri Lanka  New Zealand   Nottingham             80          59
# 17471   Bangladesh     Pakistan    Cape Town             84          58
# 44914        India    Australia    Melbourne            143          24
#
#        wickets_left       crr  last_five
# 31759            10  8.482759       41.0
# ...

# %%
y_train
# Out:
# 31759    177
# 48639    171
# 45350    140
# 18984    145
# 27724    147
#         ...
# 23942    172
# 47070    201
# 21445    158
# 17471    140
# 44914    184
# Name: runs_x, Length: 30781, dtype: int64

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

# %%
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.9867811317524127
# 1.6994485458564361

# %%
import xgboost
xgboost.__version__
# Out:
# '1.5.2'

# %%
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
import sklearn
sklearn.__version__
# Out:
# '0.24.1'
